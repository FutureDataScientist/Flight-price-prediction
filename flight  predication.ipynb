# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("flight data.csv")

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df.shape
# Out:
# (10683, 11)

# %%
df1=pd.read_csv("flight test.csv")

# %%
df1.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info

# %%
df1.shape
# Out:
# (2671, 10)

# %%
total_df=df.append(df1,sort=False)

# %%
total_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0
# 1    05:50         13:15   7h 25m     2 stops         No info   7662.0
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0
# 3    18:05         23:30   5h 25m      1 stop         No info   6218.0
# 4    16:50         21:35   4h 45m      1 stop         No info  13302.0

# %%
total_df.shape
# Out:
# (13354, 11)

# %%
df['Airline'].value_counts()
# Out:
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1752
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: Airline, dtype: int64

# %%
sns.catplot(y='Price',x='Airline',data=df.sort_values('Price',ascending=False),kind="boxen",height=6,aspect=3)
plt.show()

# %%
df['Source'].value_counts()
# Out:
# Delhi       4537
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: Source, dtype: int64

# %%
sns.catplot(y='Price',x='Source',data=df.sort_values('Price',ascending=False),kind="boxen",height=6,aspect=3)
plt.show()

# %%
df['Destination'].value_counts()
# Out:
# Cochin       4537
# Banglore     2871
# Delhi        1265
# New Delhi     932
# Hyderabad     697
# Kolkata       381
# Name: Destination, dtype: int64

# %%
sns.catplot(y='Price',x='Destination',data=df.sort_values('Price',ascending=False),kind="boxen",height=6,aspect=3)
plt.show()

# %%
df['Duration'].value_counts()
# Out:
# 2h 50m     550
# 1h 30m     386
# 2h 45m     337
# 2h 55m     337
# 2h 35m     329
#           ...
# 31h 30m      1
# 30h 25m      1
# 42h 5m       1
# 4h 10m       1
# 47h 40m      1
# Name: Duration, Length: 368, dtype: int64

# %%
total_df['Date']=total_df['Date_of_Journey'].str.split('/').str[0]
total_df['Month']=total_df['Date_of_Journey'].str.split('/').str[1]
total_df['Year']=total_df['Date_of_Journey'].str.split('/').str[2]

# %%
total_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price Date  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0   24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662.0    1
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0    9
# 3    18:05         23:30   5h 25m      1 stop         No info   6218.0   12
# 4    16:50         21:35   4h 45m      1 stop         No info  13302.0   01
#
#   Month  Year
# 0    03  2019
# 1    05  2019
# 2    06  2019
# 3    05  2019
# 4    03  2019

# %%
total_df=total_df.drop(['Date_of_Journey'],axis=1)

# %%
total_df.dtypes
# Out:
# Airline             object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Arrival_Time        object
# Duration            object
# Total_Stops         object
# Additional_Info     object
# Price              float64
# Date                object
# Month               object
# Year                object
# dtype: object

# %%
total_df['Date']=total_df['Date'].astype(int)
total_df['Month']=total_df['Month'].astype(int)
total_df['Year']=total_df['Year'].astype(int)

# %%
total_df.dtypes
# Out:
# Airline             object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Arrival_Time        object
# Duration            object
# Total_Stops         object
# Additional_Info     object
# Price              float64
# Date                 int32
# Month                int32
# Year                 int32
# dtype: object

# %%
total_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#    Arrival_Time Duration Total_Stops Additional_Info    Price  Date  Month  \
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897.0    24      3
# 1         13:15   7h 25m     2 stops         No info   7662.0     1      5
# 2  04:25 10 Jun      19h     2 stops         No info  13882.0     9      6
# 3         23:30   5h 25m      1 stop         No info   6218.0    12      5
# 4         21:35   4h 45m      1 stop         No info  13302.0     1      3
#
#    Year
# 0  2019
# 1  2019
# 2  2019
# 3  2019
# 4  2019

# %%
total_df['Additional_Info'].value_counts()
# Out:
# No info                         10493
# In-flight meal not included      2426
# No check-in baggage included      396
# 1 Long layover                     20
# Change airports                     8
# Business class                      5
# No Info                             3
# 1 Short layover                     1
# Red-eye flight                      1
# 2 Long layover                      1
# Name: Additional_Info, dtype: int64

# %%
sns.catplot(y='Price',x='Additional_Info',data= df.sort_values('Price',ascending=False),kind="boxen",height=6, aspect=3)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
total_df['Arrival_Time']=total_df['Arrival_Time'].str.split(' ').str[0]

# %%
total_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops Additional_Info    Price  Date  Month  \
# 0        01:10   2h 50m    non-stop         No info   3897.0    24      3
# 1        13:15   7h 25m     2 stops         No info   7662.0     1      5
# 2        04:25      19h     2 stops         No info  13882.0     9      6
# 3        23:30   5h 25m      1 stop         No info   6218.0    12      5
# 4        21:35   4h 45m      1 stop         No info  13302.0     1      3
#
#    Year
# 0  2019
# 1  2019
# 2  2019
# 3  2019
# 4  2019

# %%
total_df['Total_Stops'].value_counts()
# Out:
# 1 stop      7056
# non-stop    4340
# 2 stops     1899
# 3 stops       56
# 4 stops        2
# Name: Total_Stops, dtype: int64

# %%
total_df['Total_Stops']=total_df['Total_Stops'].fillna('1 stop')

# %%
total_df['Total_Stops'].isnull().sum()
# Out:
# 0

# %%
total_df['Total_Stops']=total_df['Total_Stops'].replace('non-stop','0 step')

# %%
total_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops Additional_Info    Price  Date  Month  \
# 0        01:10   2h 50m      0 step         No info   3897.0    24      3
# 1        13:15   7h 25m     2 stops         No info   7662.0     1      5
# 2        04:25      19h     2 stops         No info  13882.0     9      6
# 3        23:30   5h 25m      1 stop         No info   6218.0    12      5
# 4        21:35   4h 45m      1 stop         No info  13302.0     1      3
#
#    Year
# 0  2019
# 1  2019
# 2  2019
# 3  2019
# 4  2019

# %%
total_df['Stop'] = total_df['Total_Stops'].str.split(' ').str[0]

# %%
total_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops Additional_Info    Price  Date  Month  \
# 0        01:10   2h 50m      0 step         No info   3897.0    24      3
# 1        13:15   7h 25m     2 stops         No info   7662.0     1      5
# 2        04:25      19h     2 stops         No info  13882.0     9      6
# 3        23:30   5h 25m      1 stop         No info   6218.0    12      5
# 4        21:35   4h 45m      1 stop         No info  13302.0     1      3
#
#    Year Stop
# 0  2019    0
# 1  2019    2
# 2  2019    2
# 3  2019    1
# 4  2019    1

# %%
total_df=total_df.drop(['Total_Stops'],axis=1)

# %%
total_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Additional_Info    Price  Date  Month  Year Stop
# 0        01:10   2h 50m         No info   3897.0    24      3  2019    0
# 1        13:15   7h 25m         No info   7662.0     1      5  2019    2
# 2        04:25      19h         No info  13882.0     9      6  2019    2
# 3        23:30   5h 25m         No info   6218.0    12      5  2019    1
# 4        21:35   4h 45m         No info  13302.0     1      3  2019    1

# %%
total_df.dtypes
# Out:
# Airline             object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Arrival_Time        object
# Duration            object
# Additional_Info     object
# Price              float64
# Date                 int32
# Month                int32
# Year                 int32
# Stop                object
# dtype: object

# %%
total_df['Stop']=total_df['Stop'].astype(int)

# %%
total_df.dtypes
# Out:
# Airline             object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Arrival_Time        object
# Duration            object
# Additional_Info     object
# Price              float64
# Date                 int32
# Month                int32
# Year                 int32
# Stop                 int32
# dtype: object

# %%
total_df['Arrival_Hour'] = total_df['Arrival_Time'] .str.split(':').str[0]
total_df['Arrival_Minute'] = total_df['Arrival_Time'] .str.split(':').str[1]

# %%
total_df['Arrival_Hour']=total_df['Arrival_Hour'].astype(int)
total_df['Arrival_Minute']=total_df['Arrival_Minute'].astype(int)
total_df=total_df.drop(['Arrival_Time'],axis=1)

# %%
total_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50   4h 45m
#
#   Additional_Info    Price  Date  Month  Year  Stop  Arrival_Hour  \
# 0         No info   3897.0    24      3  2019     0             1
# 1         No info   7662.0     1      5  2019     2            13
# 2         No info  13882.0     9      6  2019     2             4
# 3         No info   6218.0    12      5  2019     1            23
# 4         No info  13302.0     1      3  2019     1            21
#
#    Arrival_Minute
# 0              10
# 1              15
# 2              25
# 3              30
# 4              35

# %%
total_df['Departure_Hour'] = total_df['Dep_Time'] .str.split(':').str[0]
total_df['Departure_Minute'] = total_df['Dep_Time'] .str.split(':').str[1]

# %%
total_df['Departure_Hour']=total_df['Departure_Hour'].astype(int)
total_df['Departure_Minute']=total_df['Departure_Minute'].astype(int)
total_df=total_df.drop(['Dep_Time'],axis=1)

# %%
total_df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#   Additional_Info    Price  Date  Month  Year  Stop  Arrival_Hour  \
# 0         No info   3897.0    24      3  2019     0             1
# 1         No info   7662.0     1      5  2019     2            13
# 2         No info  13882.0     9      6  2019     2             4
# 3         No info   6218.0    12      5  2019     1            23
# 4         No info  13302.0     1      3  2019     1            21
#
#    Arrival_Minute  Departure_Hour  Departure_Minute
# 0              10              22                20
# 1              15               5                50
# 2              25               9                25
# 3              30              18                 5
# 4              35              16                50

# %%
total_df['Route_1']= total_df['Route'].str.split('→ ').str[0]
total_df['Route_2']= total_df['Route'].str.split('→ ').str[1]
total_df['Route_3']= total_df['Route'].str.split('→ ').str[2]
total_df['Route_4']= total_df['Route'].str.split('→ ').str[3]
total_df['Route_5']= total_df['Route'].str.split('→ ').str[4]

# %%
total_df['Route_1'].fillna("None",inplace=True)
total_df['Route_2'].fillna("None",inplace=True)
total_df['Route_3'].fillna("None",inplace=True)
total_df['Route_4'].fillna("None",inplace=True)
total_df['Route_5'].fillna("None",inplace=True)

# %%
total_df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#   Additional_Info    Price  Date  Month  Year  Stop  Arrival_Hour  \
# 0         No info   3897.0    24      3  2019     0             1
# 1         No info   7662.0     1      5  2019     2            13
# 2         No info  13882.0     9      6  2019     2             4
# 3         No info   6218.0    12      5  2019     1            23
# 4         No info  13302.0     1      3  2019     1            21
#
#    Arrival_Minute  Departure_Hour  Departure_Minute Route_1 Route_2 Route_3  \
# 0              10              22                20    BLR      DEL    None
# 1              15               5                50    CCU     IXR     BBI
# 2              25               9                25    DEL     LKO     BOM
# 3              30              18                 5    CCU     NAG      BLR
# 4              35              16                50    BLR     NAG      DEL
#
#   Route_4 Route_5
# 0    None    None
# 1     BLR    None
# 2     COK    None
# 3    None    None
# 4    None    None

# %%
total_df=total_df.drop(['Route'],axis=1)
total_df=total_df.drop(['Duration'],axis=1)

# %%
total_df.head()
# Out:
#        Airline    Source Destination Additional_Info    Price  Date  Month  \
# 0       IndiGo  Banglore   New Delhi         No info   3897.0    24      3
# 1    Air India   Kolkata    Banglore         No info   7662.0     1      5
# 2  Jet Airways     Delhi      Cochin         No info  13882.0     9      6
# 3       IndiGo   Kolkata    Banglore         No info   6218.0    12      5
# 4       IndiGo  Banglore   New Delhi         No info  13302.0     1      3
#
#    Year  Stop  Arrival_Hour  Arrival_Minute  Departure_Hour  Departure_Minute  \
# 0  2019     0             1              10              22                20
# 1  2019     2            13              15               5                50
# 2  2019     2             4              25               9                25
# 3  2019     1            23              30              18                 5
# 4  2019     1            21              35              16                50
#
#   Route_1 Route_2 Route_3 Route_4 Route_5
# 0    BLR      DEL    None    None    None
# 1    CCU     IXR     BBI      BLR    None
# 2    DEL     LKO     BOM      COK    None
# 3    CCU     NAG      BLR    None    None
# 4    BLR     NAG      DEL    None    None

# %%
total_df.isnull().sum()
# Out:
# Airline                0
# Source                 0
# Destination            0
# Additional_Info        0
# Price               2671
# Date                   0
# Month                  0
# Year                   0
# Stop                   0
# Arrival_Hour           0
# Arrival_Minute         0
# Departure_Hour         0
# Departure_Minute       0
# Route_1                0
# Route_2                0
# Route_3                0
# Route_4                0
# Route_5                0
# dtype: int64

# %%
total_df['Price'].fillna((total_df['Price'].mean()),inplace=True)

# %%
total_df.isnull().sum()
# Out:
# Airline             0
# Source              0
# Destination         0
# Additional_Info     0
# Price               0
# Date                0
# Month               0
# Year                0
# Stop                0
# Arrival_Hour        0
# Arrival_Minute      0
# Departure_Hour      0
# Departure_Minute    0
# Route_1             0
# Route_2             0
# Route_3             0
# Route_4             0
# Route_5             0
# dtype: int64

# %%
total_df.head()
# Out:
#        Airline    Source Destination Additional_Info    Price  Date  Month  \
# 0       IndiGo  Banglore   New Delhi         No info   3897.0    24      3
# 1    Air India   Kolkata    Banglore         No info   7662.0     1      5
# 2  Jet Airways     Delhi      Cochin         No info  13882.0     9      6
# 3       IndiGo   Kolkata    Banglore         No info   6218.0    12      5
# 4       IndiGo  Banglore   New Delhi         No info  13302.0     1      3
#
#    Year  Stop  Arrival_Hour  Arrival_Minute  Departure_Hour  Departure_Minute  \
# 0  2019     0             1              10              22                20
# 1  2019     2            13              15               5                50
# 2  2019     2             4              25               9                25
# 3  2019     1            23              30              18                 5
# 4  2019     1            21              35              16                50
#
#   Route_1 Route_2 Route_3 Route_4 Route_5
# 0    BLR      DEL    None    None    None
# 1    CCU     IXR     BBI      BLR    None
# 2    DEL     LKO     BOM      COK    None
# 3    CCU     NAG      BLR    None    None
# 4    BLR     NAG      DEL    None    None

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
total_df["Airline"]=le.fit_transform(total_df['Airline'])
total_df["Source"]=le.fit_transform(total_df['Source'])
total_df["Destination"]=le.fit_transform(total_df['Destination'])
total_df["Additional_Info"]=le.fit_transform(total_df['Additional_Info'])
total_df["Route_1"]=le.fit_transform(total_df['Route_1'])
total_df["Route_2"]=le.fit_transform(total_df['Route_2'])
total_df["Route_3"]=le.fit_transform(total_df['Route_3'])
total_df["Route_4"]=le.fit_transform(total_df['Route_4'])
total_df["Route_5"]=le.fit_transform(total_df['Route_5'])

# %%
total_df.head()
# Out:
#    Airline  Source  Destination  Additional_Info    Price  Date  Month  Year  \
# 0        3       0            5                8   3897.0    24      3  2019
# 1        1       3            0                8   7662.0     1      5  2019
# 2        4       2            1                8  13882.0     9      6  2019
# 3        3       3            0                8   6218.0    12      5  2019
# 4        3       0            5                8  13302.0     1      3  2019
#
#    Stop  Arrival_Hour  Arrival_Minute  Departure_Hour  Departure_Minute  \
# 0     0             1              10              22                20
# 1     2            13              15               5                50
# 2     2             4              25               9                25
# 3     1            23              30              18                 5
# 4     1            21              35              16                50
#
#    Route_1  Route_2  Route_3  Route_4  Route_5
# 0        0       13       24       12        4
# 1        2       25        1        3        4
# 2        3       32        4        5        4
# 3        2       34        3       12        4
# 4        0       34        8       12        4

# %%
total_df= total_df.drop(['Year'], axis=1)

# %%
total_df.head()
# Out:
#    Airline  Source  Destination  Additional_Info    Price  Date  Month  Stop  \
# 0        3       0            5                8   3897.0    24      3     0
# 1        1       3            0                8   7662.0     1      5     2
# 2        4       2            1                8  13882.0     9      6     2
# 3        3       3            0                8   6218.0    12      5     1
# 4        3       0            5                8  13302.0     1      3     1
#
#    Arrival_Hour  Arrival_Minute  Departure_Hour  Departure_Minute  Route_1  \
# 0             1              10              22                20        0
# 1            13              15               5                50        2
# 2             4              25               9                25        3
# 3            23              30              18                 5        2
# 4            21              35              16                50        0
#
#    Route_2  Route_3  Route_4  Route_5
# 0       13       24       12        4
# 1       25        1        3        4
# 2       32        4        5        4
# 3       34        3       12        4
# 4       34        8       12        4

# %%
x= total_df.drop(['Price'],axis=1)
y= total_df['Price']

# %%
x.head()
# Out:
#    Airline  Source  Destination  Additional_Info  Date  Month  Stop  \
# 0        3       0            5                8    24      3     0
# 1        1       3            0                8     1      5     2
# 2        4       2            1                8     9      6     2
# 3        3       3            0                8    12      5     1
# 4        3       0            5                8     1      3     1
#
#    Arrival_Hour  Arrival_Minute  Departure_Hour  Departure_Minute  Route_1  \
# 0             1              10              22                20        0
# 1            13              15               5                50        2
# 2             4              25               9                25        3
# 3            23              30              18                 5        2
# 4            21              35              16                50        0
#
#    Route_2  Route_3  Route_4  Route_5
# 0       13       24       12        4
# 1       25        1        3        4
# 2       32        4        5        4
# 3       34        3       12        4
# 4       34        8       12        4

# %%
y.head()
# Out:
# 0     3897.0
# 1     7662.0
# 2    13882.0
# 3     6218.0
# 4    13302.0
# Name: Price, dtype: float64

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
model=SelectFromModel(Lasso(alpha=0.005,random_state=0))

# %%
model.fit(x_train,y_train)
# Out:
# SelectFromModel(estimator=Lasso(alpha=0.005, random_state=0))

# %%
model.get_support()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True])

# %%
selected_features=x_train.columns[(model.get_support())]

# %%
selected_features
# Out:
# Index(['Airline', 'Source', 'Destination', 'Additional_Info', 'Date', 'Month',
#        'Stop', 'Arrival_Hour', 'Arrival_Minute', 'Departure_Hour',
#        'Departure_Minute', 'Route_1', 'Route_2', 'Route_3', 'Route_4',
#        'Route_5'],
#       dtype='object')

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %%
etr = ExtraTreesRegressor()
etr.fit(x_train,y_train)
# Out:
# ExtraTreesRegressor()

# %%
plt.style.use("ggplot")
plt.figure(figsize = (15,8))
feature_importances = pd.Series(etr.feature_importances_, index=x.columns)
feature_importances.nlargest(35).plot(kind='bar')
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor
reg_rf = RandomForestRegressor()
reg_rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = reg_rf.predict(x_test)
reg_rf.score(x_train, y_train)
# Out:
# 0.9482162123655763

# %%
reg_rf.score(x_test, y_test)
# Out:
# 0.6170882655966844

# %%
plt.style.use("ggplot")
plt.figure(figsize=(12,8))
sns.distplot(y_test-y_pred)
plt.show()
# Out:
# C:\Users\harsh\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(12,8))
plt.style.use("ggplot")
plt.scatter(y_test, y_pred, alpha = 0.5)
plt.xlabel("y_test")
plt.ylabel("y_pred")
plt.show()

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('MSE:', metrics.mean_squared_error(y_test, y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# MAE: 1528.7137089695216
# MSE: 6366212.453822102
# RMSE: 2523.135441038016

# %%
metrics.r2_score(y_test, y_pred)
# Out:
# 0.6170882655966844

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1500, num = 15)]
max_features = ['auto', 'sqrt']
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
min_samples_split = [2, 3, 5, 7, 10, 15, 100]
min_samples_leaf = [1, 2,3, 5,8, 10]

# %%
param_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

# %%
rf_random = RandomizedSearchCV(estimator = reg_rf, param_distributions = param_grid,scoring='neg_mean_squared_error', n_iter = 50, cv = 5,
                               verbose=2, random_state=42)

# %%
total_df.shape
# Out:
# (13354, 17)

# %%
rf_random.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=3, n_estimators=1100; total time=   6.7s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=3, n_estimators=1100; total time=   7.7s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=3, n_estimators=1100; total time=   6.3s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=3, n_estimators=1100; total time=   6.4s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=3, n_estimators=1100; total time=   5.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=600; total time=   1.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=600; total time=   1.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=600; total time=   1.9s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=600; total time=   1.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=600; total time=   1.6s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=600; total time=   8.6s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=600; total time=   8.4s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=600; total time=   8.3s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=600; total time=   8.7s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=600; total time=   8.8s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=700; total time=  10.0s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=700; total time=   9.7s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=700; total time=   9.7s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=700; total time=   9.9s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=700; total time=  10.0s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=200; total time=   3.1s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=200; total time=   3.1s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=200; total time=   3.0s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=200; total time=   3.0s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=200; total time=   3.3s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=800; total time=   3.1s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=800; total time=   3.0s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=800; total time=   3.0s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=800; total time=   3.2s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=100, n_estimators=800; total time=   4.1s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=7, n_estimators=300; total time=   4.2s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=7, n_estimators=300; total time=   4.1s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=7, n_estimators=300; total time=   3.8s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=7, n_estimators=300; total time=   3.7s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=7, n_estimators=300; total time=   3.6s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   2.8s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   2.8s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   2.8s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   3.1s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   2.9s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=1100; total time=   5.1s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=1100; total time=   5.0s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=1100; total time=   5.4s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=1100; total time=   5.2s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=1100; total time=   6.0s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=8, min_samples_split=7, n_estimators=200; total time=   1.3s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=8, min_samples_split=7, n_estimators=200; total time=   1.3s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=8, min_samples_split=7, n_estimators=200; total time=   1.3s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=8, min_samples_split=7, n_estimators=200; total time=   1.3s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=8, min_samples_split=7, n_estimators=200; total time=   1.3s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=3, min_samples_split=15, n_estimators=1000; total time=  14.4s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=3, min_samples_split=15, n_estimators=1000; total time=  14.4s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=3, min_samples_split=15, n_estimators=1000; total time=  14.1s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=3, min_samples_split=15, n_estimators=1000; total time=  14.2s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=3, min_samples_split=15, n_estimators=1000; total time=  13.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=   1.7s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=   1.4s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=   1.4s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=   1.5s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=   1.4s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=1400; total time=  17.0s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=1400; total time=  16.4s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=1400; total time=  16.7s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=1400; total time=  16.8s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=10, min_samples_split=2, n_estimators=1400; total time=  16.9s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700; total time=   3.1s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700; total time=   3.5s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700; total time=   3.4s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700; total time=   3.1s
# [CV] END max_depth=25, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700; total time=   3.2s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=15, n_estimators=1000; total time=   5.3s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=15, n_estimators=1000; total time=   5.0s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=15, n_estimators=1000; total time=   4.9s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=15, n_estimators=1000; total time=   5.2s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=15, n_estimators=1000; total time=   4.9s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=700; total time=   4.9s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=700; total time=   4.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=700; total time=   5.0s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=700; total time=   4.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=700; total time=   4.6s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=1000; total time=  16.3s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=1000; total time=  14.1s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=1000; total time=  15.3s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=1000; total time=  16.9s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=1000; total time=  15.4s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=1100; total time=   8.2s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=1100; total time=  11.6s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=1100; total time=  12.9s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=1100; total time=  10.1s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=1100; total time=   9.9s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=600; total time=   7.4s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=600; total time=   8.9s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=600; total time=   7.9s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=600; total time=   6.6s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=600; total time=   6.6s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=3, n_estimators=700; total time=   3.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=3, n_estimators=700; total time=   3.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=3, n_estimators=700; total time=   3.3s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=3, n_estimators=700; total time=   3.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=10, min_samples_split=3, n_estimators=700; total time=   3.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   1.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   1.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   1.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   1.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   1.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=700; total time=   3.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=700; total time=   2.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=700; total time=   2.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=700; total time=   2.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=700; total time=   2.8s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=10, min_samples_split=7, n_estimators=200; total time=   2.5s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=10, min_samples_split=7, n_estimators=200; total time=   2.3s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=10, min_samples_split=7, n_estimators=200; total time=   2.3s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=10, min_samples_split=7, n_estimators=200; total time=   2.3s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=10, min_samples_split=7, n_estimators=200; total time=   2.3s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=500; total time=   3.8s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=500; total time=   4.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=500; total time=   3.8s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=500; total time=   3.8s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=500; total time=   3.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=3, n_estimators=400; total time=   1.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=3, n_estimators=400; total time=   1.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=3, n_estimators=400; total time=   1.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=3, n_estimators=400; total time=   1.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=3, n_estimators=400; total time=   1.6s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=   2.8s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=   2.7s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=   2.7s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=   2.9s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=   2.7s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1200; total time=  23.2s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1200; total time=  23.4s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1200; total time=  23.0s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1200; total time=  23.4s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=1200; total time=  23.2s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   1.5s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   1.5s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   1.5s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   1.6s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=100; total time=   1.8s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=3, n_estimators=1500; total time=   4.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=3, n_estimators=1500; total time=   4.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=3, n_estimators=1500; total time=   4.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=3, n_estimators=1500; total time=   4.4s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=3, n_estimators=1500; total time=   4.0s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1100; total time=   6.7s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1100; total time=   7.1s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1100; total time=   6.7s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1100; total time=   7.1s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=1100; total time=   6.9s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=1100; total time=   6.0s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=1100; total time=   6.3s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=1100; total time=   6.0s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=1100; total time=   6.2s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=3, n_estimators=1100; total time=   5.9s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=3, n_estimators=800; total time=  11.3s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=3, n_estimators=800; total time=  11.3s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=3, n_estimators=800; total time=  10.9s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=3, n_estimators=800; total time=  11.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=3, n_estimators=800; total time=  11.1s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=100, n_estimators=700; total time=   7.0s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=100, n_estimators=700; total time=   6.9s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=100, n_estimators=700; total time=   7.1s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=100, n_estimators=700; total time=   6.9s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=100, n_estimators=700; total time=   7.2s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=8, min_samples_split=2, n_estimators=1400; total time=   6.4s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=8, min_samples_split=2, n_estimators=1400; total time=   6.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=8, min_samples_split=2, n_estimators=1400; total time=   6.5s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=8, min_samples_split=2, n_estimators=1400; total time=   6.5s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=8, min_samples_split=2, n_estimators=1400; total time=   6.7s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=1000; total time=  13.6s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=1000; total time=  13.2s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=1000; total time=  13.2s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=1000; total time=  13.4s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=1000; total time=  13.4s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=8, min_samples_split=7, n_estimators=1000; total time=   6.6s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=8, min_samples_split=7, n_estimators=1000; total time=   6.8s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=8, min_samples_split=7, n_estimators=1000; total time=   6.6s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=8, min_samples_split=7, n_estimators=1000; total time=   6.8s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=8, min_samples_split=7, n_estimators=1000; total time=   6.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=5, n_estimators=300; total time=   0.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=5, n_estimators=300; total time=   0.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=5, n_estimators=300; total time=   0.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=5, n_estimators=300; total time=   0.7s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=5, n_estimators=300; total time=   0.7s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=  13.9s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=  13.8s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=  13.9s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=  14.0s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=  14.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=7, n_estimators=800; total time=   3.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=7, n_estimators=800; total time=   3.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=7, n_estimators=800; total time=   3.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=7, n_estimators=800; total time=   3.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=7, n_estimators=800; total time=   3.3s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=300; total time=   4.3s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=300; total time=   4.3s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=300; total time=   4.3s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=300; total time=   4.2s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=300; total time=   4.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=3, n_estimators=700; total time=   7.6s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=3, n_estimators=700; total time=   7.3s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=3, n_estimators=700; total time=   7.6s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=3, n_estimators=700; total time=   7.5s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=3, n_estimators=700; total time=   7.6s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=1000; total time=   6.6s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=1000; total time=   6.7s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=1000; total time=   6.6s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=1000; total time=   6.6s
# [CV] END max_depth=5, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=1000; total time=   6.8s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   3.7s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   3.7s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   3.9s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   3.7s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   3.6s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   7.2s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   7.3s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   7.1s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   7.3s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=500; total time=   7.1s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=600; total time=   7.5s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=600; total time=   7.1s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=600; total time=   7.4s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=600; total time=   7.2s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=8, min_samples_split=10, n_estimators=600; total time=   7.5s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=900; total time=   5.4s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=900; total time= 6.4min
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=900; total time=   8.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=900; total time=   7.7s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=900; total time=   6.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   5.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   5.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   4.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   5.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   6.4s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=  10.9s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   9.9s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   9.7s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   9.4s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   9.7s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=100; total time=   0.5s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=100; total time=   0.5s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=100; total time=   0.5s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=100; total time=   0.5s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=7, n_estimators=100; total time=   0.5s
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_iter=50,
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 3, 5, 8, 10],
#                                         'min_samples_split': [2, 3, 5, 7, 10,
#                                                               15, 100],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100, 1200,
#                                                          1300, 1400, 1500]},
#                    random_state=42, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 700,
#  'min_samples_split': 3,
#  'min_samples_leaf': 1,
#  'max_features': 'sqrt',
#  'max_depth': 15}

# %%
reg_rf = RandomForestRegressor(n_estimators= 700,
 min_samples_split=3,
 min_samples_leaf= 1,
 max_features='sqrt',
 max_depth= 15)

# %%
reg_rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=15, max_features='sqrt', min_samples_split=3,
#                       n_estimators=700)

# %%
ypred1= reg_rf.predict(x_test)

# %%
ypred1
# Out:
# array([10225.59976252,  9004.18520624,  8780.87953962, ...,
#         4446.88232221,  7894.11845498,  9852.91054612])

# %%
plt.style.use("ggplot")
plt.figure(figsize=(12,8))
sns.distplot(y_test-ypred1)
plt.show()
# Out:
# C:\Users\harsh\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(12,8))
plt.style.use("ggplot")
plt.scatter(y_test, ypred1, alpha = 0.5)
plt.xlabel("y_test")
plt.ylabel("y_predq")
plt.show()

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, ypred1))
print('MSE:', metrics.mean_squared_error(y_test, ypred1))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, ypred1)))
# Out:
# MAE: 1558.1056030397215
# MSE: 6098951.385770125
# RMSE: 2469.6055121760087

# %%
test_prediction=ypred1.astype(int)

# %%
test_prediction_df=pd.DataFrame({"Price":test_prediction})

# %%
test_prediction_df.to_csv("Output.csv")

# %%
test_prediction_df
# Out:
#       Price
# 0     10225
# 1      9004
# 2      8780
# 3     13152
# 4      3629
# ...     ...
# 4002   7157
# 4003   7311
# 4004   4446
# 4005   7894
# 4006   9852
#
# [4007 rows x 1 columns]
